# %% [markdown]
# ####In this Notebook, We'll train a CNN model to recognise face emotions. This model is similar to ResNet50 in architecture.
#
# Note: This notebook was originally committed on Kaggle. Update the code and filepaths accordingly.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/fer2013/fer2013.csv

# %% [markdown]
# **Let us first import the needed packages.**

# %%
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model

from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow
# %matplotlib inline

import keras.backend as K
K.set_image_data_format('channels_last')
K.set_learning_phase(1)

# %% [markdown]
# **Create a directory to save our generated models.**

# %%
os.mkdir("./model")

# %% [markdown]
# **Define the identity block helper function.**

# %%
def identity_block(X, f, filters, stage, block):
    """
    Implementation of the identity block
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    
    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value. You'll need this later to add back to the main path. 
    X_shortcut = X
    
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    
   
    # Second component of main path
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path 
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation 
    X = Add()([X_shortcut,X])
    X = Activation("relu")(X)
        
    return X

# %% [markdown]
# **Define the covolutional block helper function.**

# %%
def convolutional_block(X, f, filters, stage, block, s = 2):
    """
    Implementation of the convolutional block4
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    s -- Integer, specifying the stride to be used
    
    Returns:
    X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path 
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a',padding = 'valid', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    
    # Second component of main path 
    X = Conv2D(F2, (f, f), strides = (1,1), name = conv_name_base + '2b',padding = 'same', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path 
    X = Conv2D(F3, (1, 1), strides = (1,1), name = conv_name_base + '2c',padding = 'valid', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    ##### SHORTCUT PATH #### 
    X_shortcut = Conv2D(F3, (1, 1), strides = (s,s), name = conv_name_base + '1',padding = 'valid', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation 
    X = Add()([X_shortcut,X])
    X = Activation("relu")(X)
        
    return X

# %% [markdown]
# **Merge them together into the model.**

# %%
def Net50(input_shape = (48,48,1), classes = 7):
    """
    Implementation of the popular ResNet50 the following architecture:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> TOPLAYER

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """
    
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    
    # Zero-Padding
    #X = ZeroPadding2D((1, 1))(X_input)
    X = X_input
    # Stage 1

    X = Conv2D(8, (3, 3), strides = (1, 1), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    # removed maxpool
    #X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [32, 32, 128], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [32, 32, 128], stage=2, block='b')
    X = identity_block(X, 3, [32, 32, 128], stage=2, block='c')


    # Stage 3 
    X = convolutional_block(X, f = 3, filters = [64,64,256], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [64,64,256], stage=3, block='b')
    X = identity_block(X, 3, [64,64,256], stage=3, block='c')
    X = identity_block(X, 3, [64,64,256], stage=3, block='d')

    # Stage 4 
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='d')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='e')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='f')

    # Stage 5 
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=5, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=5, block='c')

    # AVGPOOL . 
    X = AveragePooling2D((2,2), name='avg_pool')(X)
    
    # output layer
    X = Flatten()(X)
    X = Dense(512, activation = 'relu', name='fc1024' , kernel_initializer = glorot_uniform(seed=0))(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)
    
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name='Net50')

    return model

# %% [markdown]
# **Load and preprocess the dataset.**

# %%
import cv2
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
import tensorflow as tf
 
dataset_path = '../input/fer2013/fer2013.csv'
image_size=(48,48)
batch_size = 32

def load_fer2013():
    data = pd.read_csv(dataset_path)
    data = (data[data['pixels'].notnull()])
    pixels = data['pixels'].tolist()
    width, height = 48, 48
    faces = []
    for pixel_sequence in pixels:
        face = [int(pixel) for pixel in pixel_sequence.split(' ')]
        face = np.asarray(face).reshape(width, height)
        face = cv2.resize(face.astype('uint8'),image_size)
        faces.append(face.astype('float32'))
    faces = np.asarray(faces)
    faces = np.expand_dims(faces, -1)
    emotions = (data['emotion'])#.values
    return faces, emotions
 
def preprocess_input(x, v2=True):
    x = x.astype('float32')
    x = x / 255.0
    if v2:
        x = x - 0.5
        x = x * 2.0
    return x
 
faces, emotions = load_fer2013()
faces = preprocess_input(faces)
xtrain, xtest,ytrain,ytest = train_test_split(faces, emotions,test_size=0.2,shuffle=True)
#Data Augumentation
data_generator = ImageDataGenerator(
                        featurewise_center=False,
                        featurewise_std_normalization=False,
                        rotation_range=10,
                        shear_range = 10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True)

# %% [markdown]
# **Declaring hyperparameters and callbacks.**

# %%
batch_size = 32
num_epochs = 150
input_shape = (48, 48, 1)
verbose = 1
num_classes = 7
patience = 25
base_path = './model/'
l2_regularization=0.01

# callbacks
log_file_path = base_path + '_emotion_training.log'
csv_logger = CSVLogger(log_file_path, append=False)
early_stop = EarlyStopping('val_loss', patience=patience)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1, patience=int(patience/2), verbose=1)
trained_models_path = base_path + '_mini_XCEPTION'
model_names = trained_models_path + '.{epoch:02d}-{val_accuracy:.2f}.hdf5'
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1,save_best_only=True)
callbacks = [model_checkpoint, csv_logger, early_stop, reduce_lr]

# %% [markdown]
# **Compile the model.**

# %%
from keras.optimizers import Adam, SGD
model = Net50(input_shape = (48, 48, 1), classes = 7)
optimizer = Adam(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-7)
model.compile(optimizer= optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "Net50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 48, 48, 1)]  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 46, 46, 8)    80          input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 46, 46, 8)    32          conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 46, 46, 8)    0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 46, 46, 32)   288         activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 46, 46, 32)   128         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 46, 46, 32)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 46, 46, 32)   9248        activation_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 46, 46, 32)   128         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 46, 46, 32)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 46, 46, 128)  1152        activation[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 46, 46, 128)  4224        activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 46, 46, 128)  512         res2a_branch1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 46, 46, 128)  512         res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 46, 46, 128)  0           bn2a_branch1[0][0]
#                                                                  bn2a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 46, 46, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 46, 46, 32)   4128        activation_3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 46, 46, 32)   128         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 46, 46, 32)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 46, 46, 32)   9248        activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 46, 46, 32)   128         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 46, 46, 32)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 46, 46, 128)  4224        activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 46, 46, 128)  512         res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 46, 46, 128)  0           activation_3[0][0]
#                                                                  bn2b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 46, 46, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 46, 46, 32)   4128        activation_6[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 46, 46, 32)   128         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 46, 46, 32)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 46, 46, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 46, 46, 32)   128         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 46, 46, 32)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 46, 46, 128)  4224        activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 46, 46, 128)  512         res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 46, 46, 128)  0           activation_6[0][0]
#                                                                  bn2c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 46, 46, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 23, 23, 64)   8256        activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 23, 23, 64)   256         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 23, 23, 64)   0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 23, 23, 64)   36928       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 23, 23, 64)   256         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 23, 23, 64)   0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 23, 23, 256)  33024       activation_9[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 23, 23, 256)  16640       activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 23, 23, 256)  1024        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 23, 23, 256)  1024        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 23, 23, 256)  0           bn3a_branch1[0][0]
#                                                                  bn3a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 23, 23, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 23, 23, 64)   16448       activation_12[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 23, 23, 64)   256         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 23, 23, 64)   0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 23, 23, 64)   36928       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 23, 23, 64)   256         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 23, 23, 64)   0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 23, 23, 256)  16640       activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 23, 23, 256)  1024        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 23, 23, 256)  0           activation_12[0][0]
#                                                                  bn3b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 23, 23, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 23, 23, 64)   16448       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 23, 23, 64)   256         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 23, 23, 64)   0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 23, 23, 64)   36928       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 23, 23, 64)   256         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 23, 23, 64)   0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 23, 23, 256)  16640       activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 23, 23, 256)  1024        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 23, 23, 256)  0           activation_15[0][0]
#                                                                  bn3c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 23, 23, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 23, 23, 64)   16448       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 23, 23, 64)   256         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 23, 23, 64)   0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 23, 23, 64)   36928       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 23, 23, 64)   256         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 23, 23, 64)   0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 23, 23, 256)  16640       activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 23, 23, 256)  1024        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 23, 23, 256)  0           activation_18[0][0]
#                                                                  bn3d_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 23, 23, 256)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 12, 12, 128)  32896       activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 12, 12, 128)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 12, 12, 128)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 12, 12, 512)  131584      activation_21[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 12, 12, 512)  2048        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 12, 12, 512)  0           bn4a_branch1[0][0]
#                                                                  bn4a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 12, 12, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_24[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 12, 12, 128)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 12, 12, 128)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 12, 12, 512)  0           activation_24[0][0]
#                                                                  bn4b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 512)  0           add_8[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_27[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 12, 12, 128)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 12, 12, 128)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 12, 12, 512)  0           activation_27[0][0]
#                                                                  bn4c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 512)  0           add_9[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_30[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 12, 12, 128)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 12, 12, 128)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 12, 12, 512)  0           activation_30[0][0]
#                                                                  bn4d_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 12, 12, 512)  0           add_10[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_33[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 12, 12, 128)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 12, 12, 128)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 12, 12, 512)  0           activation_33[0][0]
#                                                                  bn4e_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 12, 12, 512)  0           add_11[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_36[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 12, 12, 128)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 12, 12, 128)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 12, 12, 512)  0           activation_36[0][0]
#                                                                  bn4f_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 12, 12, 512)  0           add_12[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 6, 6, 256)    131328      activation_39[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 6, 6, 256)    1024        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 6, 6, 256)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 6, 6, 256)    590080      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 6, 6, 256)    1024        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 6, 6, 256)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 6, 6, 1024)   525312      activation_39[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 6, 6, 1024)   263168      activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 6, 6, 1024)   4096        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 6, 6, 1024)   4096        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 6, 6, 1024)   0           bn5a_branch1[0][0]
#                                                                  bn5a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 6, 6, 1024)   0           add_13[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 6, 6, 256)    262400      activation_42[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 6, 6, 256)    1024        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 6, 6, 256)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 6, 6, 256)    590080      activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 6, 6, 256)    1024        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 6, 6, 256)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 6, 6, 1024)   263168      activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 6, 6, 1024)   4096        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 6, 6, 1024)   0           activation_42[0][0]
#                                                                  bn5b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 6, 6, 1024)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 6, 6, 256)    262400      activation_45[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 6, 6, 256)    1024        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 6, 6, 256)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 6, 6, 256)    590080      activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 6, 6, 256)    1024        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 6, 6, 256)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 6, 6, 1024)   263168      activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 6, 6, 1024)   4096        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 6, 6, 1024)   0           activation_45[0][0]
#                                                                  bn5c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 6, 6, 1024)   0           add_15[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 3, 3, 1024)   0           activation_48[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 9216)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc1024 (Dense)                  (None, 512)          4719104     flatten[0][0]
# __________________________________________________________________________________________________
# fc7 (Dense)                     (None, 7)            3591        fc1024[0][0]
# ==================================================================================================
# Total params: 10,646,583
# Trainable params: 10,620,071
# Non-trainable params: 26,512
# __________________________________________________________________________________________________

# %%
history = model.fit(data_generator.flow(xtrain, ytrain,),
                        steps_per_epoch=len(xtrain) / batch_size,
                        epochs=num_epochs, verbose=1, callbacks=callbacks,
                        validation_data= (xtest,ytest))
# Out:
# Epoch 1/150
# 898/897 [==============================] - ETA: 0s - loss: 1.9550 - accuracy: 0.2622
# Epoch 00001: val_loss improved from inf to 1.70921, saving model to ./model/_mini_XCEPTION.01-0.32.hdf5
# 898/897 [==============================] - 61s 67ms/step - loss: 1.9550 - accuracy: 0.2622 - val_loss: 1.7092 - val_accuracy: 0.3171
# Epoch 2/150
# 898/897 [==============================] - ETA: 0s - loss: 1.5579 - accuracy: 0.3851
# Epoch 00002: val_loss improved from 1.70921 to 1.54297, saving model to ./model/_mini_XCEPTION.02-0.41.hdf5
# 898/897 [==============================] - 60s 67ms/step - loss: 1.5579 - accuracy: 0.3851 - val_loss: 1.5430 - val_accuracy: 0.4092
# Epoch 3/150
# 898/897 [==============================] - ETA: 0s - loss: 1.4018 - accuracy: 0.4504
# Epoch 00003: val_loss improved from 1.54297 to 1.34008, saving model to ./model/_mini_XCEPTION.03-0.48.hdf5
# 898/897 [==============================] - 60s 67ms/step - loss: 1.4018 - accuracy: 0.4504 - val_loss: 1.3401 - val_accuracy: 0.4756
# Epoch 4/150
# 898/897 [==============================] - ETA: 0s - loss: 1.3037 - accuracy: 0.4953
# Epoch 00004: val_loss did not improve from 1.34008
# 898/897 [==============================] - 59s 66ms/step - loss: 1.3037 - accuracy: 0.4953 - val_loss: 1.7360 - val_accuracy: 0.3369
# Epoch 5/150
# 898/897 [==============================] - ETA: 0s - loss: 1.2482 - accuracy: 0.5158
# Epoch 00005: val_loss improved from 1.34008 to 1.32800, saving model to ./model/_mini_XCEPTION.05-0.48.hdf5
# 898/897 [==============================] - 82s 91ms/step - loss: 1.2482 - accuracy: 0.5158 - val_loss: 1.3280 - val_accuracy: 0.4806
# Epoch 6/150
# 898/897 [==============================] - ETA: 0s - loss: 1.2078 - accuracy: 0.5360
# Epoch 00006: val_loss improved from 1.32800 to 1.17360, saving model to ./model/_mini_XCEPTION.06-0.56.hdf5
# 898/897 [==============================] - 60s 67ms/step - loss: 1.2078 - accuracy: 0.5360 - val_loss: 1.1736 - val_accuracy: 0.5568
# Epoch 7/150
# 898/897 [==============================] - ETA: 0s - loss: 1.1630 - accuracy: 0.5577
# Epoch 00007: val_loss did not improve from 1.17360
# 898/897 [==============================] - 59s 66ms/step - loss: 1.1630 - accuracy: 0.5577 - val_loss: 1.1992 - val_accuracy: 0.5532
# Epoch 8/150
# 898/897 [==============================] - ETA: 0s - loss: 1.1423 - accuracy: 0.5659
# Epoch 00008: val_loss did not improve from 1.17360
# 898/897 [==============================] - 59s 66ms/step - loss: 1.1423 - accuracy: 0.5659 - val_loss: 1.2895 - val_accuracy: 0.5004
# Epoch 9/150
# 898/897 [==============================] - ETA: 0s - loss: 1.1097 - accuracy: 0.5770
# Epoch 00009: val_loss did not improve from 1.17360
# 898/897 [==============================] - 70s 77ms/step - loss: 1.1097 - accuracy: 0.5770 - val_loss: 1.2471 - val_accuracy: 0.5500
# Epoch 10/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0867 - accuracy: 0.5878
# Epoch 00010: val_loss improved from 1.17360 to 1.09888, saving model to ./model/_mini_XCEPTION.10-0.58.hdf5
# 898/897 [==============================] - 59s 66ms/step - loss: 1.0867 - accuracy: 0.5878 - val_loss: 1.0989 - val_accuracy: 0.5850
# Epoch 11/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0691 - accuracy: 0.5950
# Epoch 00011: val_loss improved from 1.09888 to 1.07184, saving model to ./model/_mini_XCEPTION.11-0.60.hdf5
# 898/897 [==============================] - 60s 67ms/step - loss: 1.0691 - accuracy: 0.5950 - val_loss: 1.0718 - val_accuracy: 0.5965
# Epoch 12/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0419 - accuracy: 0.6073
# Epoch 00012: val_loss improved from 1.07184 to 1.06681, saving model to ./model/_mini_XCEPTION.12-0.60.hdf5
# 898/897 [==============================] - 61s 68ms/step - loss: 1.0419 - accuracy: 0.6073 - val_loss: 1.0668 - val_accuracy: 0.6023
# Epoch 13/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0285 - accuracy: 0.6116
# Epoch 00013: val_loss improved from 1.06681 to 1.06336, saving model to ./model/_mini_XCEPTION.13-0.60.hdf5
# 898/897 [==============================] - 61s 68ms/step - loss: 1.0285 - accuracy: 0.6116 - val_loss: 1.0634 - val_accuracy: 0.5986
# Epoch 14/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0104 - accuracy: 0.6193
# Epoch 00014: val_loss did not improve from 1.06336
# 898/897 [==============================] - 59s 65ms/step - loss: 1.0104 - accuracy: 0.6193 - val_loss: 1.0754 - val_accuracy: 0.6076
# Epoch 15/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9901 - accuracy: 0.6279
# Epoch 00015: val_loss did not improve from 1.06336
# 898/897 [==============================] - 59s 65ms/step - loss: 0.9901 - accuracy: 0.6279 - val_loss: 1.0992 - val_accuracy: 0.5985
# Epoch 16/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9777 - accuracy: 0.6330
# Epoch 00016: val_loss did not improve from 1.06336
# 898/897 [==============================] - 57s 64ms/step - loss: 0.9777 - accuracy: 0.6330 - val_loss: 1.0740 - val_accuracy: 0.6119
# Epoch 17/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9666 - accuracy: 0.6371
# Epoch 00017: val_loss improved from 1.06336 to 1.01703, saving model to ./model/_mini_XCEPTION.17-0.62.hdf5
# 898/897 [==============================] - 60s 67ms/step - loss: 0.9666 - accuracy: 0.6371 - val_loss: 1.0170 - val_accuracy: 0.6225
# Epoch 18/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9531 - accuracy: 0.6404
# Epoch 00018: val_loss did not improve from 1.01703
# 898/897 [==============================] - 59s 66ms/step - loss: 0.9531 - accuracy: 0.6404 - val_loss: 1.0171 - val_accuracy: 0.6248
# Epoch 19/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9391 - accuracy: 0.6472
# Epoch 00019: val_loss did not improve from 1.01703
# 898/897 [==============================] - 61s 68ms/step - loss: 0.9391 - accuracy: 0.6472 - val_loss: 1.0713 - val_accuracy: 0.6096
# Epoch 20/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9276 - accuracy: 0.6528
# Epoch 00020: val_loss did not improve from 1.01703
# 898/897 [==============================] - 62s 69ms/step - loss: 0.9276 - accuracy: 0.6528 - val_loss: 1.0342 - val_accuracy: 0.6151
# Epoch 21/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9168 - accuracy: 0.6558
# Epoch 00021: val_loss did not improve from 1.01703
# 898/897 [==============================] - 60s 66ms/step - loss: 0.9168 - accuracy: 0.6558 - val_loss: 1.0475 - val_accuracy: 0.6279
# Epoch 22/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9090 - accuracy: 0.6587
# Epoch 00022: val_loss improved from 1.01703 to 1.01082, saving model to ./model/_mini_XCEPTION.22-0.63.hdf5
# 898/897 [==============================] - 58s 65ms/step - loss: 0.9090 - accuracy: 0.6587 - val_loss: 1.0108 - val_accuracy: 0.6340
# Epoch 23/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8923 - accuracy: 0.6652
# Epoch 00023: val_loss improved from 1.01082 to 0.94834, saving model to ./model/_mini_XCEPTION.23-0.65.hdf5
# 898/897 [==============================] - 60s 67ms/step - loss: 0.8923 - accuracy: 0.6652 - val_loss: 0.9483 - val_accuracy: 0.6507
# Epoch 24/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8887 - accuracy: 0.6681
# Epoch 00024: val_loss did not improve from 0.94834
# 898/897 [==============================] - 60s 66ms/step - loss: 0.8887 - accuracy: 0.6681 - val_loss: 1.0707 - val_accuracy: 0.6199
# Epoch 25/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8754 - accuracy: 0.6709
# Epoch 00025: val_loss did not improve from 0.94834
# 898/897 [==============================] - 60s 67ms/step - loss: 0.8754 - accuracy: 0.6709 - val_loss: 0.9981 - val_accuracy: 0.6488
# Epoch 26/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8629 - accuracy: 0.6769
# Epoch 00026: val_loss did not improve from 0.94834
# 898/897 [==============================] - 58s 65ms/step - loss: 0.8629 - accuracy: 0.6769 - val_loss: 0.9704 - val_accuracy: 0.6385
# Epoch 27/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8523 - accuracy: 0.6817
# Epoch 00027: val_loss did not improve from 0.94834
# 898/897 [==============================] - 59s 66ms/step - loss: 0.8523 - accuracy: 0.6817 - val_loss: 1.0348 - val_accuracy: 0.6262
# Epoch 28/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8469 - accuracy: 0.6830
# Epoch 00028: val_loss did not improve from 0.94834
# 898/897 [==============================] - 57s 64ms/step - loss: 0.8469 - accuracy: 0.6830 - val_loss: 0.9763 - val_accuracy: 0.6471
# Epoch 29/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8349 - accuracy: 0.6909
# Epoch 00029: val_loss did not improve from 0.94834
# 898/897 [==============================] - 57s 64ms/step - loss: 0.8349 - accuracy: 0.6909 - val_loss: 0.9538 - val_accuracy: 0.6602
# Epoch 30/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8261 - accuracy: 0.6897
# Epoch 00030: val_loss did not improve from 0.94834
# 898/897 [==============================] - 59s 66ms/step - loss: 0.8261 - accuracy: 0.6897 - val_loss: 0.9590 - val_accuracy: 0.6555
# Epoch 31/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8145 - accuracy: 0.6955
# Epoch 00031: val_loss improved from 0.94834 to 0.94650, saving model to ./model/_mini_XCEPTION.31-0.66.hdf5
# 898/897 [==============================] - 58s 64ms/step - loss: 0.8145 - accuracy: 0.6955 - val_loss: 0.9465 - val_accuracy: 0.6605
# Epoch 32/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8051 - accuracy: 0.6986
# Epoch 00032: val_loss did not improve from 0.94650
# 898/897 [==============================] - 59s 66ms/step - loss: 0.8051 - accuracy: 0.6986 - val_loss: 0.9667 - val_accuracy: 0.6503
# Epoch 33/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8017 - accuracy: 0.7002
# Epoch 00033: val_loss did not improve from 0.94650
# 898/897 [==============================] - 57s 63ms/step - loss: 0.8017 - accuracy: 0.7002 - val_loss: 0.9473 - val_accuracy: 0.6602
# Epoch 34/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7840 - accuracy: 0.7078
# Epoch 00034: val_loss did not improve from 0.94650
# 898/897 [==============================] - 58s 65ms/step - loss: 0.7840 - accuracy: 0.7078 - val_loss: 0.9681 - val_accuracy: 0.6538
# Epoch 35/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7764 - accuracy: 0.7111
# Epoch 00035: val_loss did not improve from 0.94650
# 898/897 [==============================] - 57s 64ms/step - loss: 0.7764 - accuracy: 0.7111 - val_loss: 1.0310 - val_accuracy: 0.6411
# Epoch 36/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7702 - accuracy: 0.7127
# Epoch 00036: val_loss did not improve from 0.94650
# 898/897 [==============================] - 57s 63ms/step - loss: 0.7702 - accuracy: 0.7127 - val_loss: 0.9996 - val_accuracy: 0.6438
# Epoch 37/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7537 - accuracy: 0.7171
# Epoch 00037: val_loss improved from 0.94650 to 0.93407, saving model to ./model/_mini_XCEPTION.37-0.67.hdf5
# 898/897 [==============================] - 60s 67ms/step - loss: 0.7537 - accuracy: 0.7171 - val_loss: 0.9341 - val_accuracy: 0.6659
# Epoch 38/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7555 - accuracy: 0.7183
# Epoch 00038: val_loss did not improve from 0.93407
# 898/897 [==============================] - 57s 63ms/step - loss: 0.7555 - accuracy: 0.7183 - val_loss: 0.9489 - val_accuracy: 0.6606
# Epoch 39/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7410 - accuracy: 0.7233
# Epoch 00039: val_loss did not improve from 0.93407
# 898/897 [==============================] - 66s 73ms/step - loss: 0.7410 - accuracy: 0.7233 - val_loss: 1.0586 - val_accuracy: 0.6441
# Epoch 40/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7411 - accuracy: 0.7225
# Epoch 00040: val_loss did not improve from 0.93407
# 898/897 [==============================] - 57s 63ms/step - loss: 0.7411 - accuracy: 0.7225 - val_loss: 1.0175 - val_accuracy: 0.6492
# Epoch 41/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7260 - accuracy: 0.7307
# Epoch 00041: val_loss did not improve from 0.93407
# 898/897 [==============================] - 57s 63ms/step - loss: 0.7260 - accuracy: 0.7307 - val_loss: 0.9695 - val_accuracy: 0.6623
# Epoch 42/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7216 - accuracy: 0.7289
# Epoch 00042: val_loss did not improve from 0.93407
# 898/897 [==============================] - 59s 66ms/step - loss: 0.7216 - accuracy: 0.7289 - val_loss: 0.9974 - val_accuracy: 0.6446
# Epoch 43/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7099 - accuracy: 0.7352
# Epoch 00043: val_loss did not improve from 0.93407
# 898/897 [==============================] - 71s 79ms/step - loss: 0.7099 - accuracy: 0.7352 - val_loss: 0.9816 - val_accuracy: 0.6537
# Epoch 44/150
# 898/897 [==============================] - ETA: 0s - loss: 0.6993 - accuracy: 0.7400
# Epoch 00044: val_loss did not improve from 0.93407
# 898/897 [==============================] - 62s 69ms/step - loss: 0.6993 - accuracy: 0.7400 - val_loss: 0.9602 - val_accuracy: 0.6608
# Epoch 45/150
# 898/897 [==============================] - ETA: 0s - loss: 0.6956 - accuracy: 0.7391
# Epoch 00045: val_loss did not improve from 0.93407
# 898/897 [==============================] - 57s 64ms/step - loss: 0.6956 - accuracy: 0.7391 - val_loss: 0.9633 - val_accuracy: 0.6634
# Epoch 46/150
# 898/897 [==============================] - ETA: 0s - loss: 0.6792 - accuracy: 0.7473
# Epoch 00046: val_loss did not improve from 0.93407
# 898/897 [==============================] - 58s 65ms/step - loss: 0.6792 - accuracy: 0.7473 - val_loss: 0.9783 - val_accuracy: 0.6672
# Epoch 47/150
# 898/897 [==============================] - ETA: 0s - loss: 0.6737 - accuracy: 0.7499
# Epoch 00047: val_loss did not improve from 0.93407
# 898/897 [==============================] - 57s 64ms/step - loss: 0.6737 - accuracy: 0.7499 - val_loss: 0.9753 - val_accuracy: 0.6570
# Epoch 48/150
# 898/897 [==============================] - ETA: 0s - loss: 0.6689 - accuracy: 0.7518
# Epoch 00048: val_loss did not improve from 0.93407
# 898/897 [==============================] - 56s 63ms/step - loss: 0.6689 - accuracy: 0.7518 - val_loss: 0.9601 - val_accuracy: 0.6728
# Epoch 49/150
# 898/897 [==============================] - ETA: 0s - loss: 0.6574 - accuracy: 0.7556
# Epoch 00049: val_loss did not improve from 0.93407
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# 898/897 [==============================] - 60s 66ms/step - loss: 0.6574 - accuracy: 0.7556 - val_loss: 0.9533 - val_accuracy: 0.6669
# Epoch 50/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5834 - accuracy: 0.7848
# Epoch 00050: val_loss improved from 0.93407 to 0.92777, saving model to ./model/_mini_XCEPTION.50-0.69.hdf5
# 898/897 [==============================] - 57s 64ms/step - loss: 0.5834 - accuracy: 0.7848 - val_loss: 0.9278 - val_accuracy: 0.6906
# Epoch 51/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5492 - accuracy: 0.7977
# Epoch 00051: val_loss did not improve from 0.92777
# 898/897 [==============================] - 59s 66ms/step - loss: 0.5492 - accuracy: 0.7977 - val_loss: 0.9416 - val_accuracy: 0.6857
# Epoch 52/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5366 - accuracy: 0.8053
# Epoch 00052: val_loss did not improve from 0.92777
# 898/897 [==============================] - 58s 65ms/step - loss: 0.5366 - accuracy: 0.8053 - val_loss: 0.9519 - val_accuracy: 0.6874
# Epoch 53/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5285 - accuracy: 0.8036
# Epoch 00053: val_loss did not improve from 0.92777
# 898/897 [==============================] - 57s 63ms/step - loss: 0.5285 - accuracy: 0.8036 - val_loss: 0.9533 - val_accuracy: 0.6943
# Epoch 54/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5209 - accuracy: 0.8056
# Epoch 00054: val_loss did not improve from 0.92777
# 898/897 [==============================] - 60s 67ms/step - loss: 0.5209 - accuracy: 0.8056 - val_loss: 0.9569 - val_accuracy: 0.6907
# Epoch 55/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5181 - accuracy: 0.8113
# Epoch 00055: val_loss did not improve from 0.92777
# 898/897 [==============================] - 56s 63ms/step - loss: 0.5181 - accuracy: 0.8113 - val_loss: 0.9622 - val_accuracy: 0.6863
# Epoch 56/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5086 - accuracy: 0.8142
# Epoch 00056: val_loss did not improve from 0.92777
# 898/897 [==============================] - 57s 63ms/step - loss: 0.5086 - accuracy: 0.8142 - val_loss: 0.9734 - val_accuracy: 0.6865
# Epoch 57/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5084 - accuracy: 0.8138
# Epoch 00057: val_loss did not improve from 0.92777
# 898/897 [==============================] - 56s 63ms/step - loss: 0.5084 - accuracy: 0.8138 - val_loss: 0.9593 - val_accuracy: 0.6890
# Epoch 58/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5001 - accuracy: 0.8161
# Epoch 00058: val_loss did not improve from 0.92777
# 898/897 [==============================] - 56s 63ms/step - loss: 0.5001 - accuracy: 0.8161 - val_loss: 0.9615 - val_accuracy: 0.6878
# Epoch 59/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4966 - accuracy: 0.8181
# Epoch 00059: val_loss did not improve from 0.92777
# 898/897 [==============================] - 60s 67ms/step - loss: 0.4966 - accuracy: 0.8181 - val_loss: 0.9705 - val_accuracy: 0.6896
# Epoch 60/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4914 - accuracy: 0.8195
# Epoch 00060: val_loss did not improve from 0.92777
# 898/897 [==============================] - 56s 63ms/step - loss: 0.4914 - accuracy: 0.8195 - val_loss: 0.9791 - val_accuracy: 0.6889
# Epoch 61/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4883 - accuracy: 0.8216
# Epoch 00061: val_loss did not improve from 0.92777
# 898/897 [==============================] - 57s 63ms/step - loss: 0.4883 - accuracy: 0.8216 - val_loss: 0.9790 - val_accuracy: 0.6885
# Epoch 62/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4823 - accuracy: 0.8224
# Epoch 00062: val_loss did not improve from 0.92777
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# 898/897 [==============================] - 57s 63ms/step - loss: 0.4823 - accuracy: 0.8224 - val_loss: 0.9802 - val_accuracy: 0.6917
# Epoch 63/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4738 - accuracy: 0.8252
# Epoch 00063: val_loss did not improve from 0.92777
# 898/897 [==============================] - 59s 66ms/step - loss: 0.4738 - accuracy: 0.8252 - val_loss: 0.9845 - val_accuracy: 0.6882
# Epoch 64/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4694 - accuracy: 0.8265
# Epoch 00064: val_loss did not improve from 0.92777
# 898/897 [==============================] - 59s 66ms/step - loss: 0.4694 - accuracy: 0.8265 - val_loss: 0.9830 - val_accuracy: 0.6904
# Epoch 65/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4694 - accuracy: 0.8288
# Epoch 00065: val_loss did not improve from 0.92777
# 898/897 [==============================] - 56s 62ms/step - loss: 0.4694 - accuracy: 0.8288 - val_loss: 0.9874 - val_accuracy: 0.6882
# Epoch 66/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4684 - accuracy: 0.8273
# Epoch 00066: val_loss did not improve from 0.92777
# 898/897 [==============================] - 56s 63ms/step - loss: 0.4684 - accuracy: 0.8273 - val_loss: 0.9838 - val_accuracy: 0.6904
# Epoch 67/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4678 - accuracy: 0.8297
# Epoch 00067: val_loss did not improve from 0.92777
# 898/897 [==============================] - 56s 63ms/step - loss: 0.4678 - accuracy: 0.8297 - val_loss: 0.9873 - val_accuracy: 0.6900
# Epoch 68/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4708 - accuracy: 0.8270
# Epoch 00068: val_loss did not improve from 0.92777
# 898/897 [==============================] - 60s 67ms/step - loss: 0.4708 - accuracy: 0.8270 - val_loss: 0.9853 - val_accuracy: 0.6903
# Epoch 69/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4670 - accuracy: 0.8277
# Epoch 00069: val_loss did not improve from 0.92777
# 898/897 [==============================] - 57s 63ms/step - loss: 0.4670 - accuracy: 0.8277 - val_loss: 0.9873 - val_accuracy: 0.6911
# Epoch 70/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.8289
# Epoch 00070: val_loss did not improve from 0.92777
# 898/897 [==============================] - 56s 63ms/step - loss: 0.4640 - accuracy: 0.8289 - val_loss: 0.9912 - val_accuracy: 0.6903
# Epoch 71/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4637 - accuracy: 0.8322
# Epoch 00071: val_loss did not improve from 0.92777
# 898/897 [==============================] - 56s 63ms/step - loss: 0.4637 - accuracy: 0.8322 - val_loss: 0.9905 - val_accuracy: 0.6907
# Epoch 72/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4654 - accuracy: 0.8286
# Epoch 00072: val_loss did not improve from 0.92777
# 898/897 [==============================] - 56s 63ms/step - loss: 0.4654 - accuracy: 0.8286 - val_loss: 0.9912 - val_accuracy: 0.6900
# Epoch 73/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4598 - accuracy: 0.8318
# Epoch 00073: val_loss did not improve from 0.92777
# 898/897 [==============================] - 61s 68ms/step - loss: 0.4598 - accuracy: 0.8318 - val_loss: 0.9938 - val_accuracy: 0.6896
# Epoch 74/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4610 - accuracy: 0.8295
# Epoch 00074: val_loss did not improve from 0.92777
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 5.000000328436726e-07.
# 898/897 [==============================] - 57s 63ms/step - loss: 0.4610 - accuracy: 0.8295 - val_loss: 0.9946 - val_accuracy: 0.6903
# Epoch 75/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4659 - accuracy: 0.8312
# Epoch 00075: val_loss did not improve from 0.92777
# 898/897 [==============================] - 57s 63ms/step - loss: 0.4659 - accuracy: 0.8312 - val_loss: 0.9947 - val_accuracy: 0.6909

# %% [markdown]
# **Plot performance metrics.**

# %%
import keras
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
testloss = model.evaluate(xtest, ytest) 
print("Test Loss " + str(testloss[0]))
print("Test Acc: " + str(testloss[1]))
trainloss = model.evaluate(xtrain, ytrain) 
print("Train Loss " + str(trainloss[0]))
print("Train Acc: " + str(trainloss[1]))
# Out:
# 225/225 [==============================] - 4s 17ms/step - loss: 0.9947 - accuracy: 0.6909
# Test Loss 0.9946961402893066
# Test Acc: 0.6908609867095947
# 898/898 [==============================] - 15s 16ms/step - loss: 0.4257 - accuracy: 0.8445
# Train Loss 0.42565596103668213
# Train Acc: 0.8444738388061523

# %% [markdown]
# We've achieved **69%** accuracy on the validation set which is approximately 4% beyond human-level accuracy.

# %% [markdown]
# **Visualizing model architecture.**

# %%
plot_model(model, to_file='model.png')
SVG(model_to_dot(model).create(prog='dot', format='svg'))
